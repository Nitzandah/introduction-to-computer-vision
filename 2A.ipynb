# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img_NZ_bgr = cv2.imread("New_Zealand_Lake.jpg",cv2.IMREAD_COLOR)
b,g,r = cv2.split(img_NZ_bgr)
plt.subplot(141);plt.imshow(r,cmap='gray');plt.title("Red Channel");

# %%
# Generate random data from a Gaussian distribution with mean = 0 and standard deviation = 1
noise = np.random.normal(0, 1, 1000000)

# Plot a histogram of the data
plt.hist(data, bins=50, density=True, )

# Set the plot title and axis labels
plt.title('Histogram of Gaussian Distribution')
plt.xlabel('Value')
plt.ylabel('Density')

# Show the plot
plt.show()

# %%
plt.imshow(r)

# %%
noise = np.random.rand(r.shape[0],r.shape[1])
r_with_noise=noise*2+r
plt.imshow(r_with_noise)

# %%
plt.plot(r[50:51,:][0])

# %%
plt.plot(r_with_noise[50:51,:][0])
